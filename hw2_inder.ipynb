# %% [markdown]
# ## Question 1

# %% [markdown]
# ### GENE A

# %%
df<-read.csv("normal_skewed_distr.csv")
head(df)
# Out:
#   geneC geneB geneA
# 1 82    22    67
# 2 67    37    67
# 3 85     1    55
# 4 64    49    46
# 5 85    45    50
# 6 60    13    38

# %%
# measure of central tendency
# compute mean
m<-mean(df$geneA)
# measure of spread using standard deviation
s<-sd(df$geneA)

# sd and coverage/intervals
# using 68–95–99.7 rule find the interval for 68%, 95% and 99.7% 
# for 68% - mean plus/minus one standard deviation
# check proporation our data points covered within this range
lt=m-s # lower limit of the range
ut=m+s # upper limit of the range
# number of data points within that range divided by total number of data points 
length(df$geneA[df$geneA>=lt & df$geneA<=ut])/length(df$geneA)*100

# for 95% - mean plus/minus two standard deviation
# higlight those ranges in the plot
# check proporation our data points covered within this range
lt=m-2*s # lower limit of the range
ut=m+2*s # upper limit of the range
# number of data points within that range divided by total number of data points
length(df$geneA[df$geneA>=lt & df$geneA<=ut])/length(df$geneA)*100

# for 99% - mean plus/minus three standard deviation
# higlight those ranges in the plot
# check proporation our data points covered within this range
lt=m-3*s # lower limit of the range
ut=m+3*s # upper limit of the range
# number of data points within that range divided by total number of data points
length(df$geneA[df$geneA>=lt & df$geneA<=ut])/length(df$geneA)*100

# z-score - to find how many standard deviation away from the mean for a given observation
zscore<-(df$geneA-m)/s

# view actual and z-score value as two columns
head(cbind(df$geneA, zscore))
# Out:
# [1] 65.3
# [1] 95.6
# [1] 100
#         zscore
# [1,] 67  1.06895604
# [2,] 67  1.06895604
# [3,] 55  0.29551784
# [4,] 46 -0.28456080
# [5,] 50 -0.02674807
# [6,] 38 -0.80018626

# %%
hist(df$geneA, xlab="expression of geneA", main="Histogram of geneA")
abline(v=m, col="red", lw=3)
abline(v=c(m-s, m+s), lty=2, lw=2, col="blue")
abline(v=c(m-2*s, m+2*s), lty=2, lw=2, col="blue")
abline(v=c(m-3*s, m+3*s), lty=2, lw=2, col="blue")
hist(zscore, xlab="zscore of expression of geneA")
# Out:
# Plot with title “Histogram of geneA”
# Plot with title “Histogram of zscore”

# %% [markdown]
# ### GENE B

# %%
# measure of central tendency
# compute mean
m<-mean(df$geneB)
# measure of spread using standard deviation
s<-sd(df$geneB)

# sd and coverage/intervals
# using 68–95–99.7 rule find the interval for 68%, 95% and 99.7% 
# for 68% - mean plus/minus one standard deviation
# check proporation our data points covered within this range
lt=m-s # lower limit of the range
ut=m+s # upper limit of the range
# number of data points within that range divided by total number of data points 
length(df$geneB[df$geneB>=lt & df$geneB<=ut])/length(df$geneB)*100

# for 95% - mean plus/minus two standard deviation
# higlight those ranges in the plot
# check proporation our data points covered within this range
lt=m-2*s # lower limit of the range
ut=m+2*s # upper limit of the range
# number of data points within that range divided by total number of data points
length(df$geneB[df$geneB>=lt & df$geneB<=ut])/length(df$geneB)*100

# for 99% - mean plus/minus three standard deviation
# higlight those ranges in the plot
# check proporation our data points covered within this range
lt=m-3*s # lower limit of the range
ut=m+3*s # upper limit of the range
# number of data points within that range divided by total number of data points
length(df$geneB[df$geneB>=lt & df$geneB<=ut])/length(df$geneB)*100

# z-score - to find how many standard deviation away from the mean for a given observation
zscore<-(df$geneB-m)/s

# view actual and z-score value as two columns
head(cbind(df$geneB, zscore))
# Out:
# [1] 68.1
# [1] 94.4
# [1] 98.8
#         zscore
# [1,] 22  0.4037569
# [2,] 37  1.4640429
# [3,]  1 -1.0806435
# [4,] 49  2.3122716
# [5,] 45  2.0295287
# [6,] 13 -0.2324147

# %%
hist(df$geneB, xlab="expression of geneB", main="Histogram of geneB")
abline(v=m, col="red", lw=3)
abline(v=c(m-s, m+s), lty=2, lw=2, col="blue")
abline(v=c(m-2*s, m+2*s), lty=2, lw=2, col="blue")
abline(v=c(m-3*s, m+3*s), lty=2, lw=2, col="blue")
hist(zscore, xlab="zscore of expression of geneB")
# Out:
# Plot with title “Histogram of geneB”
# Plot with title “Histogram of zscore”

# %% [markdown]
# ### GENE C

# %%
# measure of central tendency
# compute mean
m<-mean(df$geneC)
# measure of spread using standard deviation
s<-sd(df$geneC)
# sd and coverage/intervals
# using 68–95–99.7 rule find the interval for 68%, 95% and 99.7% 
# for 68% - mean plus/minus one standard deviation
# check proporation our data points covered within this range
lt=m-s # lower limit of the range
ut=m+s # upper limit of the range
# number of data points within that range divided by total number of data points 
length(df$geneC[df$geneC>=lt & df$geneC<=ut])/length(df$geneC)*100

# for 95% - mean plus/minus two standard deviation
# higlight those ranges in the plot
# check proporation our data points covered within this range
lt=m-2*s # lower limit of the range
ut=m+2*s # upper limit of the range
# number of data points within that range divided by total number of data points
length(df$geneC[df$geneC>=lt & df$geneC<=ut])/length(df$geneC)*100

# for 99% - mean plus/minus three standard deviation
# higlight those ranges in the plot
# check proporation our data points covered within this range
lt=m-3*s # lower limit of the range
ut=m+3*s # upper limit of the range
# number of data points within that range divided by total number of data points
length(df$geneC[df$geneC>=lt & df$geneC<=ut])/length(df$geneC)*100

# z-score - to find how many standard deviation away from the mean for a given observation
zscore<-(df$geneC-m)/s

# view actual and z-score value as two columns
head(cbind(df$geneC, zscore))
# Out:
# [1] 66.4
# [1] 96.5
# [1] 99.7
#         zscore
# [1,] 82  0.6796786
# [2,] 67 -0.2487595
# [3,] 85  0.8653663
# [4,] 64 -0.4344472
# [5,] 85  0.8653663
# [6,] 60 -0.6820307

# %%
hist(df$geneC, xlab="expression of geneC", main="Histogram of geneC")
abline(v=m, col="red", lw=3)
abline(v=c(m-s, m+s), lty=2, lw=2, col="blue")
abline(v=c(m-2*s, m+2*s), lty=2, lw=2, col="blue")
abline(v=c(m-3*s, m+3*s), lty=2, lw=2, col="blue")
hist(zscore, xlab="zscore of expression of geneC")
# Out:
# Plot with title “Histogram of geneC”
# Plot with title “Histogram of zscore”

# %% [markdown]
# The distribution of expression level of geneB,geneC follow's a skew distribution but since $95\%$ of the data lies within the $\mu\pm2\sigma$, and $\approx100\%$ of the data lies within the $\mu\pm3\sigma$ for both the z-distribution may be used to make the skew distirbution into normal distirbution.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### GeneA

# %%
geneA_sm <- c()
# using the below function to randomly select 10 data points from geneA dataset for 100 times
for(i in c(1:100)){ # iterations from 1 to 100
  sam<-sample(df$geneA, 10) # use sample function to randomly select 10 data points
  m_sam <- mean(sam) # compute the mean of sampled values
  geneA_sm <- c(geneA_sm, m_sam) # append mean value to the list
}

# plot the distribution of sample means
hist(geneA_sm, main="distribution of samples means of gene A")

# mean of sample means
mean(geneA_sm)

# standard deviation of sample means
sd(geneA_sm)

# standard error of the mean
sem<-sd(geneA_sm)/sqrt(length(geneA_sm))
sem

# compute 95% confidence interval
# first compute marginal error using z-value for 95% interval
me <- 1.96*sem
me

lower_limit = mean(geneA_sm) - me
upper_limit = mean(geneA_sm) + me
print(c(lower_limit, upper_limit))

# highlight the confidence interval in the plot
hist(geneA_sm, main="distribution of samples means of gene A")
abline(v=mean(geneA_sm), col="red", lw=2)
abline(v=c(lower_limit, upper_limit), lw=2)
# Out:
# [1] 50.97
# [1] 4.711698
# [1] 0.4711698
# [1] 0.9234929
# [1] 50.04651 51.89349
# Plot with title “distribution of samples means of gene A”

# %% [markdown]
# ### GeneB

# %%
geneB_sm <- c()
# using the below function to randomly select 10 data points from geneB dataset for 100 times
for(i in c(1:100)){ # iterations from 1 to 100
  sam<-sample(df$geneB, 10) # use sample function to randomly select 10 data points
  m_sam <- mean(sam) # compute the mean of sampled values
  geneB_sm <- c(geneB_sm, m_sam) # append mean value to the list
}

# plot the distribution of sample means
hist(geneB_sm, main="distribution of samples means of gene B")

# mean of sample means
mean(geneB_sm)

# standard deviation of sample means
sd(geneB_sm)

# standard error of the mean
sem<-sd(geneB_sm)/sqrt(length(geneB_sm))
sem

# compute 95% confidence interval
# first compute marginal error using z-value for 95% interval
me <- 1.96*sem
me

lower_limit = mean(geneB_sm) - me
upper_limit = mean(geneB_sm) + me
print(c(lower_limit, upper_limit))

# highlight the confidence interval in the plot
hist(geneB_sm, main="distribution of samples means of gene B")
abline(v=mean(geneB_sm), col="red", lw=2)
abline(v=c(lower_limit, upper_limit), lw=2)
# Out:
# [1] 16.426
# [1] 4.211351
# [1] 0.4211351
# [1] 0.8254248
# [1] 15.60058 17.25142
# Plot with title “distribution of samples means of gene B”

# %% [markdown]
# ###  GeneC

# %%
geneC_sm <- c()
# using the below function to randomly select 10 data points from geneC dataset for 100 times
for(i in c(1:100)){ # iterations from 1 to 100
  sam<-sample(df$geneC, 10) # use sample function to randomly select 10 data points
  m_sam <- mean(sam) # compute the mean of sampled values
  geneC_sm <- c(geneC_sm, m_sam) # append mean value to the list
}

# plot the distribution of sample means
hist(geneC_sm, main="distribution of samples means of gene C")

# mean of sample means
mean(geneC_sm)

# standard deviation of sample means
sd(geneC_sm)

# standard error of the mean
sem<-sd(geneC_sm)/sqrt(length(geneC_sm))
sem

# compute 95% confidence interval
# first compute marginal error using z-value for 95% interval
me <- 1.96*sem
me

lower_limit = mean(geneC_sm) - me
upper_limit = mean(geneC_sm) + me
print(c(lower_limit, upper_limit))

# highlight the confidence interval in the plot
hist(geneC_sm, main="distribution of samples means of gene C")
abline(v=mean(geneC_sm), col="red", lw=2)
abline(v=c(lower_limit, upper_limit), lw=2)
# Out:
# [1] 71.654
# [1] 4.982381
# [1] 0.4982381
# [1] 0.9765468
# [1] 70.67745 72.63055
# Plot with title “distribution of samples means of gene C”

# %% [markdown]
# ### Relation of Sample size and Standard Error of mean in GeneA

# %%
results<-c("0"=0)
for (i in c(10:200))
{
    geneA_sm <- c()
    for(j in c(1:100))
    {
        sam<-sample(df$geneA, i) # use sample function to randomly select 10 data points
        m_sam <- mean(sam) # compute the mean of sampled values
        geneA_sm <- c(geneA_sm, m_sam) # append mean value to the list
    }
    sem<-sd(geneA_sm)/sqrt(length(geneA_sm))
    results[as.character(i)]<-sem
}
results<-as.matrix(results)
x<-as.vector(as.integer((row.names(results))))
x<-as.vector(x[2:length(x)])
y<-as.vector(results[,1])
y<-as.vector(y[2:length(y)])
plot(x,y,xlab='sample_size',ylab='Standard Error of Mean',type='o',frame = TRUE)
abline(v=180,col='red',lty=2)
abline(v=200,col='blue',lty=2)
abline(h=results[172],col='red',lty=2)
abline(h=results[192],col='blue',lty=2)
# Out:
# plot without title

# %%
x<-x[172:length(x)]
y<-y[172:length(y)]
plot(x,y,xlab='sample_size',ylab='Standard Error of Mean',type='o',frame = TRUE)
# Out:
# plot without title

# %% [markdown]
# As we can see increasing the sample size decreases the standard error of mean but after certain sample size the change in the standard error of mean start to be negligible as shown by the area intersected by the red[sample_size=180] and blue[sample_size=200] line the change of standard error of mean after 180 is negligible
